# %%
import re
import os
import sys
import warnings
import pandas as pd

parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.append(parent_dir)
sys.path.append(os.path.abspath(os.path.join(parent_dir, 'statistics_dir')))

print(sys.path)
# Out:
# ['/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/home/or/dev/latin_music_statistics/lms/lib/python3.12/site-packages', '/home/or/dev/latin_music_statistics/crawler', '/home/or/dev/latin_music_statistics/crawler/gui/statistics', '/home/or/dev/latin_music_statistics/crawler', '/home/or/dev/latin_music_statistics/crawler/statistics', '/home/or/dev/latin_music_statistics/crawler', '/home/or/dev/latin_music_statistics/crawler/statistics_dir']

# %%
os.getcwd()
# Out:
# '/home/or/dev/latin_music_statistics/crawler/gui_dir'

# %%
from statistics_dir.statistics import *
df = pd.read_csv('/home/or/dev/latin_music_statistics/crawler/data_dir/processed_data.csv', encoding='utf-8')
df['all_artists'] = df.apply(lambda row: eval(row['artists']) + eval(row['featured_artists']), axis=1)

# %%
# df = pd.read_csv('/home/or/dev/latin_music_statistics/crawler/data_dir/processed_data.csv', encoding='utf-8')
df.head(2)
# Out:
#    Unnamed: 0.1  Unnamed: 0                                            url  \
# 0             1           1    https://genius.com/Aventura-obsesion-lyrics
# 1             2           2  https://genius.com/Bad-bunny-la-romana-lyrics
#
#                        title_with_artists      title        artists  \
# 0  Obsesión by Aventura (Ft. Judy Santos)   Obsesión   ['Aventura']
# 1    La Romana by Bad Bunny (Ft. El Alfa)  La Romana  ['Bad Bunny']
#
#   featured_artists                                             lyrics  \
# 0  ['Judy Santos']  37 ContributorsTranslationsEnglishDeutschObses...
# 1      ['El Alfa']  66 ContributorsTranslationsEnglishDeutschLa Ro...
#
#                                         clean_lyrics  \
# 0  \nSomething flavored Aventura\nHello\nShh solo...
# 1  \n\nPásame la hookah eh\nQue el coro ya 'tá pr...
#
#                                           norm_words  norm_w_len  \
# 0  ['something', 'flavored', 'aventura', 'hello',...         158
# 1  ['pásamar', 'hookah', 'eh', 'coro', 'tá', "pre...         343
#
#                                            sentiment selected_sentiment  \
# 0  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 1  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
#
#   song_topic                  all_artists
# 0        wow  ['Aventura', 'Judy Santos']
# 1        wow     ['Bad Bunny', 'El Alfa']

# %%
df_expanded = df.explode('all_artists')
df_expanded
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               1           1
# 1               2           2
# 2               3           3
# 3               4           4
# 4               5           5
# ..            ...         ...
# 838           986         986
# 839           987         987
# 840           988         988
# 841           989         989
# 842           990         990
#
#                                                    url  \
# 0          https://genius.com/Aventura-obsesion-lyrics
# 1        https://genius.com/Bad-bunny-la-romana-lyrics
# 2    https://genius.com/Khea-ayer-me-llamo-mi-ex-ly...
# 3    https://genius.com/Aventura-and-bad-bunny-volv...
# 4            https://genius.com/Rosalia-la-fama-lyrics
# ..                                                 ...
# 838   https://genius.com/El-cuarto-bate-xiomara-lyrics
# 839  https://genius.com/El-cuarto-bate-la-chanclete...
# 840    https://genius.com/Tony-lozano-mil-vidas-lyrics
# 841  https://genius.com/Blas-duran-jr-dejame-tener-...
# 842  https://genius.com/Blas-duran-jr-a-ti-no-te-qu...
#
#                                  title_with_artists                  title  \
# 0            Obsesión by Aventura (Ft. Judy Santos)               Obsesión
# 1              La Romana by Bad Bunny (Ft. El Alfa)              La Romana
# 2    Ayer Me Llamó Mi Ex by KHEA (Ft. Lenny Santos)    Ayer Me Llamó Mi Ex
# 3                     Volví by Aventura & Bad Bunny                  Volví
# 4               LA FAMA by ROSALÍA (Ft. The Weeknd)                LA FAMA
# ..                                              ...                    ...
# 838                       Xiomara by El Cuarto Bate                Xiomara
# 839                La Chancletera by El Cuarto Bate         La Chancletera
# 840       Mil Vidas by Tony Lozano (Ft. DerekVinci)              Mil Vidas
# 841          Déjame Tener Mi Novia by Blas Duran JR  Déjame Tener Mi Novia
# 842              A Ti No Te Quiero by Blas Duran JR      A Ti No Te Quiero
#
#                        artists  featured_artists  \
# 0                 ['Aventura']   ['Judy Santos']
# 1                ['Bad Bunny']       ['El Alfa']
# 2                     ['KHEA']  ['Lenny Santos']
# 3    ['Aventura', 'Bad Bunny']                []
# 4                  ['ROSALÍA']    ['The Weeknd']
# ..                         ...               ...
# 838         ['El Cuarto Bate']                []
# 839         ['El Cuarto Bate']                []
# 840            ['Tony Lozano']    ['DerekVinci']
# 841          ['Blas Duran JR']                []
# 842          ['Blas Duran JR']                []
#
#                                                 lyrics  \
# 0    37 ContributorsTranslationsEnglishDeutschObses...
# 1    66 ContributorsTranslationsEnglishDeutschLa Ro...
# 2    14 ContributorsAyer Me Llamó Mi Ex Lyrics[Letr...
# 3    26 ContributorsTranslationsDeutschEnglishVolví...
# 4    48 ContributorsTranslationsEnglishFrançaisItal...
# ..                                                 ...
# 838  1 ContributorXiomara LyricsXiomara eres una cr...
# 839  1 ContributorLa Chancletera LyricsTú que fuist...
# 840  1 ContributorMil Vidas LyricsAy cuéntale, a ot...
# 841  1 ContributorDéjame Tener Mi Novia LyricsMi am...
# 842  1 ContributorA Ti No Te Quiero LyricsBlas Dura...
#
#                                           clean_lyrics  \
# 0    \nSomething flavored Aventura\nHello\nShh solo...
# 1    \n\nPásame la hookah eh\nQue el coro ya 'tá pr...
# 2    \nYeah yeah yeah\nKHEA Young Flex in the game\...
# 3    \nDime por qué le tiras piedras a la luna\nTan...
# 4    \nLo que pasó a ti te lo cuento\nNo creas que ...
# ..                                                 ...
# 838  Con tus desprecios me quieres matar\nEse orgul...
# 839  La mejor de las mujeres\nEra porque no sabía\n...
# 840  Enséñale los mensajes de texto\nQue me enviaba...
# 841  no Por qué porque no tengo mi novia\n\nCoro\nS...
# 842  \nNo quiero que tu me busques\nni que mencione...
#
#                                             norm_words  norm_w_len  \
# 0    ['something', 'flavored', 'aventura', 'hello',...         158
# 1    ['pásamar', 'hookah', 'eh', 'coro', 'tá', "pre...         343
# 2    ['yeah', 'yeah', 'yeah', 'khea', 'young', 'fle...         208
# 3    ['dimir', 'tiras', 'piedra', 'luna', 'ilógico'...         179
# 4    ['pasar', 'contar', 'creer', 'doler', 'inventa...          66
# ..                                                 ...         ...
# 838  ['desprecio', 'quieres', 'matar', 'orgullo', '...          50
# 839  ['mujer', 'saber', 'vida', 'alegre', 'vistar',...          37
# 840  ['enséñalir', 'mensaje', 'texto', 'enviabar', ...         102
# 841  ['novia', 'coro', 'querer', 'amor', 'adorar', ...         157
# 842  ['querer', 'busques', 'mención', 'nombre', 'qu...          91
#
#                                              sentiment selected_sentiment  \
# 0    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 1    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 2    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 3    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 4    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# ..                                                 ...                ...
# 838  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 839  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 840  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 841  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 842  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
#
#     song_topic                    all_artists
# 0          wow    ['Aventura', 'Judy Santos']
# 1          wow       ['Bad Bunny', 'El Alfa']
# 2          wow       ['KHEA', 'Lenny Santos']
# 3          wow      ['Aventura', 'Bad Bunny']
# 4          wow      ['ROSALÍA', 'The Weeknd']
# ..         ...                            ...
# 838        wow             ['El Cuarto Bate']
# 839        wow             ['El Cuarto Bate']
# 840        wow  ['Tony Lozano', 'DerekVinci']
# 841        wow              ['Blas Duran JR']
# 842        wow              ['Blas Duran JR']
#
# [843 rows x 15 columns]

# %%
df = pd.read_csv('/home/or/dev/latin_music_statistics/crawler/data_dir/processed_data.csv', encoding='utf-8')
df['all_artists'] = df['all_artists'].apply(lambda x: eval(x))

artist_stat = calculate_artist_counts(df, 'all_artists')
diff_artists_num = len(artist_stat)
sentiment_dist = dist_sentiment(df, 'selected_sentiment')
avg_words_per_song = int(df['norm_w_len'].mean())

# return artist_stat, diff_artists_num, sentiment_dist, avg_words_per_song

# %%
from collections import Counter

# %%
def most_common_word(df, text_column, top=10):

    # all_words = df[text_column].apply(lambda x: eval(x)).explode().tolist()
    all_words = df[text_column].explode().tolist()

    word_counts = Counter(all_words)
    total_words = sum(word_counts.values())

    most_common_words = word_counts.most_common(top)

    # Calculate percentage for each word
    word_percentages = [(word, count, round(count / total_words * 100, 2)) for word, count in most_common_words]

    return word_percentages

a=most_common_word(df, 'norm_words', top=10)

# %%
df['norm_words'] = df['norm_words'].apply(lambda x: eval(x))

df.explode('norm_words')
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               1           1
# 0               1           1
# 0               1           1
# 0               1           1
# 0               1           1
# ..            ...         ...
# 842           990         990
# 842           990         990
# 842           990         990
# 842           990         990
# 842           990         990
#
#                                                    url  \
# 0          https://genius.com/Aventura-obsesion-lyrics
# 0          https://genius.com/Aventura-obsesion-lyrics
# 0          https://genius.com/Aventura-obsesion-lyrics
# 0          https://genius.com/Aventura-obsesion-lyrics
# 0          https://genius.com/Aventura-obsesion-lyrics
# ..                                                 ...
# 842  https://genius.com/Blas-duran-jr-a-ti-no-te-qu...
# 842  https://genius.com/Blas-duran-jr-a-ti-no-te-qu...
# 842  https://genius.com/Blas-duran-jr-a-ti-no-te-qu...
# 842  https://genius.com/Blas-duran-jr-a-ti-no-te-qu...
# 842  https://genius.com/Blas-duran-jr-a-ti-no-te-qu...
#
#                          title_with_artists              title  \
# 0    Obsesión by Aventura (Ft. Judy Santos)           Obsesión
# 0    Obsesión by Aventura (Ft. Judy Santos)           Obsesión
# 0    Obsesión by Aventura (Ft. Judy Santos)           Obsesión
# 0    Obsesión by Aventura (Ft. Judy Santos)           Obsesión
# 0    Obsesión by Aventura (Ft. Judy Santos)           Obsesión
# ..                                      ...                ...
# 842      A Ti No Te Quiero by Blas Duran JR  A Ti No Te Quiero
# 842      A Ti No Te Quiero by Blas Duran JR  A Ti No Te Quiero
# 842      A Ti No Te Quiero by Blas Duran JR  A Ti No Te Quiero
# 842      A Ti No Te Quiero by Blas Duran JR  A Ti No Te Quiero
# 842      A Ti No Te Quiero by Blas Duran JR  A Ti No Te Quiero
#
#                artists featured_artists  \
# 0         ['Aventura']  ['Judy Santos']
# 0         ['Aventura']  ['Judy Santos']
# 0         ['Aventura']  ['Judy Santos']
# 0         ['Aventura']  ['Judy Santos']
# 0         ['Aventura']  ['Judy Santos']
# ..                 ...              ...
# 842  ['Blas Duran JR']               []
# 842  ['Blas Duran JR']               []
# 842  ['Blas Duran JR']               []
# 842  ['Blas Duran JR']               []
# 842  ['Blas Duran JR']               []
#
#                                                 lyrics  \
# 0    37 ContributorsTranslationsEnglishDeutschObses...
# 0    37 ContributorsTranslationsEnglishDeutschObses...
# 0    37 ContributorsTranslationsEnglishDeutschObses...
# 0    37 ContributorsTranslationsEnglishDeutschObses...
# 0    37 ContributorsTranslationsEnglishDeutschObses...
# ..                                                 ...
# 842  1 ContributorA Ti No Te Quiero LyricsBlas Dura...
# 842  1 ContributorA Ti No Te Quiero LyricsBlas Dura...
# 842  1 ContributorA Ti No Te Quiero LyricsBlas Dura...
# 842  1 ContributorA Ti No Te Quiero LyricsBlas Dura...
# 842  1 ContributorA Ti No Te Quiero LyricsBlas Dura...
#
#                                           clean_lyrics norm_words  norm_w_len  \
# 0    \nSomething flavored Aventura\nHello\nShh solo...  something         158
# 0    \nSomething flavored Aventura\nHello\nShh solo...   flavored         158
# 0    \nSomething flavored Aventura\nHello\nShh solo...   aventura         158
# 0    \nSomething flavored Aventura\nHello\nShh solo...      hello         158
# 0    \nSomething flavored Aventura\nHello\nShh solo...        shh         158
# ..                                                 ...        ...         ...
# 842  \nNo quiero que tu me busques\nni que mencione...     junior          91
# 842  \nNo quiero que tu me busques\nni que mencione...       hijo          91
# 842  \nNo quiero que tu me busques\nni que mencione...     peluch          91
# 842  \nNo quiero que tu me busques\nni que mencione...     vivola          91
# 842  \nNo quiero que tu me busques\nni que mencione...     vivola          91
#
#                                              sentiment selected_sentiment  \
# 0    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 0    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 0    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 0    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 0    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# ..                                                 ...                ...
# 842  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 842  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 842  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 842  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 842  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
#
#     song_topic              all_artists
# 0          wow  [Aventura, Judy Santos]
# 0          wow  [Aventura, Judy Santos]
# 0          wow  [Aventura, Judy Santos]
# 0          wow  [Aventura, Judy Santos]
# 0          wow  [Aventura, Judy Santos]
# ..         ...                      ...
# 842        wow          [Blas Duran JR]
# 842        wow          [Blas Duran JR]
# 842        wow          [Blas Duran JR]
# 842        wow          [Blas Duran JR]
# 842        wow          [Blas Duran JR]
#
# [90614 rows x 15 columns]

# %%
norm_words
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               1           1
# 1               2           2
# 2               3           3
# 3               4           4
# 4               5           5
# ..            ...         ...
# 838           986         986
# 839           987         987
# 840           988         988
# 841           989         989
# 842           990         990
#
#                                                    url  \
# 0          https://genius.com/Aventura-obsesion-lyrics
# 1        https://genius.com/Bad-bunny-la-romana-lyrics
# 2    https://genius.com/Khea-ayer-me-llamo-mi-ex-ly...
# 3    https://genius.com/Aventura-and-bad-bunny-volv...
# 4            https://genius.com/Rosalia-la-fama-lyrics
# ..                                                 ...
# 838   https://genius.com/El-cuarto-bate-xiomara-lyrics
# 839  https://genius.com/El-cuarto-bate-la-chanclete...
# 840    https://genius.com/Tony-lozano-mil-vidas-lyrics
# 841  https://genius.com/Blas-duran-jr-dejame-tener-...
# 842  https://genius.com/Blas-duran-jr-a-ti-no-te-qu...
#
#                                  title_with_artists                  title  \
# 0            Obsesión by Aventura (Ft. Judy Santos)               Obsesión
# 1              La Romana by Bad Bunny (Ft. El Alfa)              La Romana
# 2    Ayer Me Llamó Mi Ex by KHEA (Ft. Lenny Santos)    Ayer Me Llamó Mi Ex
# 3                     Volví by Aventura & Bad Bunny                  Volví
# 4               LA FAMA by ROSALÍA (Ft. The Weeknd)                LA FAMA
# ..                                              ...                    ...
# 838                       Xiomara by El Cuarto Bate                Xiomara
# 839                La Chancletera by El Cuarto Bate         La Chancletera
# 840       Mil Vidas by Tony Lozano (Ft. DerekVinci)              Mil Vidas
# 841          Déjame Tener Mi Novia by Blas Duran JR  Déjame Tener Mi Novia
# 842              A Ti No Te Quiero by Blas Duran JR      A Ti No Te Quiero
#
#                        artists  featured_artists  \
# 0                 ['Aventura']   ['Judy Santos']
# 1                ['Bad Bunny']       ['El Alfa']
# 2                     ['KHEA']  ['Lenny Santos']
# 3    ['Aventura', 'Bad Bunny']                []
# 4                  ['ROSALÍA']    ['The Weeknd']
# ..                         ...               ...
# 838         ['El Cuarto Bate']                []
# 839         ['El Cuarto Bate']                []
# 840            ['Tony Lozano']    ['DerekVinci']
# 841          ['Blas Duran JR']                []
# 842          ['Blas Duran JR']                []
#
#                                                 lyrics  \
# 0    37 ContributorsTranslationsEnglishDeutschObses...
# 1    66 ContributorsTranslationsEnglishDeutschLa Ro...
# 2    14 ContributorsAyer Me Llamó Mi Ex Lyrics[Letr...
# 3    26 ContributorsTranslationsDeutschEnglishVolví...
# 4    48 ContributorsTranslationsEnglishFrançaisItal...
# ..                                                 ...
# 838  1 ContributorXiomara LyricsXiomara eres una cr...
# 839  1 ContributorLa Chancletera LyricsTú que fuist...
# 840  1 ContributorMil Vidas LyricsAy cuéntale, a ot...
# 841  1 ContributorDéjame Tener Mi Novia LyricsMi am...
# 842  1 ContributorA Ti No Te Quiero LyricsBlas Dura...
#
#                                           clean_lyrics  \
# 0    \nSomething flavored Aventura\nHello\nShh solo...
# 1    \n\nPásame la hookah eh\nQue el coro ya 'tá pr...
# 2    \nYeah yeah yeah\nKHEA Young Flex in the game\...
# 3    \nDime por qué le tiras piedras a la luna\nTan...
# 4    \nLo que pasó a ti te lo cuento\nNo creas que ...
# ..                                                 ...
# 838  Con tus desprecios me quieres matar\nEse orgul...
# 839  La mejor de las mujeres\nEra porque no sabía\n...
# 840  Enséñale los mensajes de texto\nQue me enviaba...
# 841  no Por qué porque no tengo mi novia\n\nCoro\nS...
# 842  \nNo quiero que tu me busques\nni que mencione...
#
#                                             norm_words  norm_w_len  \
# 0    ['something', 'flavored', 'aventura', 'hello',...         158
# 1    ['pásamar', 'hookah', 'eh', 'coro', 'tá', "pre...         343
# 2    ['yeah', 'yeah', 'yeah', 'khea', 'young', 'fle...         208
# 3    ['dimir', 'tiras', 'piedra', 'luna', 'ilógico'...         179
# 4    ['pasar', 'contar', 'creer', 'doler', 'inventa...          66
# ..                                                 ...         ...
# 838  ['desprecio', 'quieres', 'matar', 'orgullo', '...          50
# 839  ['mujer', 'saber', 'vida', 'alegre', 'vistar',...          37
# 840  ['enséñalir', 'mensaje', 'texto', 'enviabar', ...         102
# 841  ['novia', 'coro', 'querer', 'amor', 'adorar', ...         157
# 842  ['querer', 'busques', 'mención', 'nombre', 'qu...          91
#
#                                              sentiment selected_sentiment  \
# 0    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 1    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 2    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 3    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 4    {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# ..                                                 ...                ...
# 838  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 839  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 840  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 841  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
# 842  {'negative': 0.8, 'positive': 0.05, 'neutral':...           negative
#
#     song_topic                all_artists
# 0          wow    [Aventura, Judy Santos]
# 1          wow       [Bad Bunny, El Alfa]
# 2          wow       [KHEA, Lenny Santos]
# 3          wow      [Aventura, Bad Bunny]
# 4          wow      [ROSALÍA, The Weeknd]
# ..         ...                        ...
# 838        wow           [El Cuarto Bate]
# 839        wow           [El Cuarto Bate]
# 840        wow  [Tony Lozano, DerekVinci]
# 841        wow            [Blas Duran JR]
# 842        wow            [Blas Duran JR]
#
# [843 rows x 15 columns]
